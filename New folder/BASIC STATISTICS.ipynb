# %%
import pandas as pd 
df = pd.read_csv("sales_data_with_discounts.csv")

# %%
#	Identify numerical columns in the dataset.
df.select_dtypes(include=['number']).columns
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Calculate the mean, median, mode, and standard deviation for these columns.
# Provide a brief interpretation of these statistics.

# %%
Volume_mean=df['Volume'].mean()
Volume_median=df['Volume'].median()
Volume_mode =df['Volume'].mode()
Volume_std = df['Volume'].std()
print("Volume_MEAN:",Volume_mean)
print("Volume_MEDIAN:",Volume_median)
print("Volume_MODE:",Volume_mode)
print("Volume_STD",Volume_std)
# Out:
# Volume_MEAN: 5.066666666666666
# Volume_MEDIAN: 4.0
# Volume_MODE: 0    3
# Name: Volume, dtype: int64
# Volume_STD 4.231602391213926

# %%
# INTERPRETATION FOR VOLUME COLUMN 
# Mean (5.07) → On average, the volume is about 5 units.
# 	Median (4.0) → The typical value is 4 units, showing most are near this level.
#	Mode (3) → The most common value is 3 units.
#	Standard Deviation (4.23) → There is some variation, but most values are close to 3–5 units.

# %%
Avg_Price_mean=df['Avg Price'].mean()
Avg_Price_median=df['Avg Price'].median()
Avg_Price_mode =df['Avg Price'].mode()
Avg_Price_std = df['Avg Price'].std()
print("Avg_Price_MEAN:",Avg_Price_mean)
print("Avg_Price_MEDIAN:",Avg_Price_median)
print("Avg_Price_MODE:",Avg_Price_mode)
print("Avg_Price_STD",Volume_std)
# Out:
# Avg_Price_MEAN: 10453.433333333332
# Avg_Price_MEDIAN: 1450.0
# Avg_Price_MODE: 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64
# Avg_Price_STD 4.231602391213926

# %%
# INTERPRETATION FOR AVG_PRICE COLUMN
# Mean (10,453) → The average price looks very high because of a few very large values.
# Median (1,450) → The typical price is much smaller; most values are closer to this level.
# Mode (400, 450, 500, etc.) → Small prices occur most often.
# Standard Deviation (4.23) → Prices don’t vary much around the average.

# %%
Total_Sales_Value_mean=df['Total Sales Value'].mean()
Total_Sales_Value_median=df['Total Sales Value'].median()
Total_Sales_Value_mode =df['Total Sales Value'].mode()
Total_Sales_Value_std = df['Total Sales Value'].std()
print("Total_Sales_Value_MEAN:",Avg_Price_mean)
print("Total_Sales_Value_MEDIAN:",Avg_Price_median)
print("Total_Sales_Value_MODE:",Avg_Price_mode)
print("Total_Sales_Value_STD",Volume_std)
# Out:
# Total_Sales_Value_MEAN: 10453.433333333332
# Total_Sales_Value_MEDIAN: 1450.0
# Total_Sales_Value_MODE: 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64
# Total_Sales_Value_STD 4.231602391213926

# %%
# INTERPRETATION FOR TOTAL_SALES_VALUE COLUMN
# Mean (10,453) → Average sales look high because of a few very large transactions.
# Median (1,450) → Typical sales are much smaller; most deals are closer to this level.
# Mode (400, 450, 500, etc.) → Small sales amounts happen most often.
# Standard Deviation (4.23) → Sales values don’t vary too much around the average.

# %%
DR_mean = df['Discount Rate (%)'].mean()

DR_median = df['Discount Rate (%)'].median()
DR_mode =df['Discount Rate (%)'].mode()
DR_std = df['Discount Rate (%)'].std()
print("Discount_Rate_MEAN:",DR_mean)
print("Discount_Rate_MEDIAN:",DR_median)
print("Discount_Rate_MODE:",DR_mode)
print("Discount_Rate_STD",DR_std)
# Out:
# Discount_Rate_MEAN: 15.155241895330914
# Discount_Rate_MEDIAN: 16.57776564929597
# Discount_Rate_MODE: 0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64
# Discount_Rate_STD 4.220602153325511

# %%
# INTERPRETATION FOR DISCOUNT RATE % COLUMN
# - Mean (15.2%) → On average, discounts are about 15%.
# Median (16.6%) → The typical discount is around 16%, close to the average.
# Mode (~5% and ~20%) → Discounts often occur at two common levels: small (around 5%) and large (around 20%).
# Standard Deviation (4.2%) → Discounts don’t vary too much; most are near the average.

# %%
DA_mean = df['Discount Amount'].mean()
print(" DA_MEAN:", DA_mean)

DA_median = df['Discount Amount'].median()
print("Discount_Amount_MEDIAN:",DA_median)

DA_mode =df['Discount Amount'].mode()
print("Discount_Amount_MODE:",DA_mode)


DA_std = df['Discount Amount'].std()
print("Discount_Amount_STD",DA_std)
# Out:
#  DA_MEAN: 3346.499424342415
# Discount_Amount_MEDIAN: 988.9337332382784
# Discount_Amount_MODE: 0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64
# Discount_Amount_STD 4509.9029633539985

# %%
# INTERPRETATION FOR DISCOUNT AMOUNT _ COLUMN
# Mean (3,346) → The average discount looks high, but it’s influenced by a few very large discounts.
# Median (989) → The typical discount is much smaller; most discounts are around this level.
# Mode (~70–100, etc.) → Small discounts occur most frequently, though there are also some repeated very large discounts.
# Standard Deviation (4,510) → Discounts vary a lot, showing big differences between small and large values.

# %%
Net_Sales_Value_mean = df['Net Sales Value'].mean()
print("Net_Sales_Value_MEAN:",Net_Sales_Value_mean)

Net_Sales_Value_median = df['Net Sales Value'].median()
print("Net_Sales_Value_MEDIAN:",Net_Sales_Value_median)

Net_Sales_Value_mode =df['Net Sales Value'].mode()
print("Net_Sales_Value_MODE:",Net_Sales_Value_mode)


Net_Sales_Value_std = df['Net Sales Value'].std()
print("Net_Sales_Value_STD",DA_std)
# Out:
# Net_Sales_Value_MEAN: 30466.336131270138
# Net_Sales_Value_MEDIAN: 4677.788059301853
# Net_Sales_Value_MODE: 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64
# Net_Sales_Value_STD 4509.9029633539985

# %%
#INTERPRETION FOR SALES_VALUE_ COLUMN
# Mean (30,466) → Average sales look very high because of a few very large deals.
# Median (4,678) → Typical sales are much smaller; most transactions are around this level.
# Mode (~300–500, etc.) → Small sales amounts happen most often, but there are also some repeated big values.
# Standard Deviation (4,510) → Sales vary a lot, showing big ups and downs.

# %%
#	Calculate the mean, median, mode, and standard deviation for these columns.
print(df.describe())
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
#Data Visualization
#Objective: To visualize the distribution and relationship of #numerical and categorical variables in the dataset.

# %%
# Histograms:
# Plot histograms for each numerical column.
# Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences

# %%
df["Volume"].hist()
# Out:
# <Axes: >

# %% [raw]
# SKEWNESS - The histogram is right-skewed. Most values are concentrated between 0 and 10, and a few extend up to 30+.
# PRESENCE OF OUTLIERS - The long tail on the right suggests the presence of outliers.
# INFERENCE - The data is not evenly distributed,	Most values are low, but a few very high values pull the average up.

# %%
df["Avg Price"].hist()
# Out:
# <Axes: >

# %% [raw]
# SKEWNESS - The histogram is right-skewed. Most values are concentrated between 0 and 20000 above ,and  few extend up to 60000
# PRESENCE OF OUTLIERS -  A few values stretch up to 60,000, indicating rare but very large entries.
# INFERENCE - - The data is not evenly spread, Most entries are small, but a few very large values pull the average up.

# %%
df["Total Sales Value"].hist()
# Out:
# <Axes: >

# %% [raw]
# The distribution is highly right-skewed, because most values are very small and a few values are extremely large.
# The large values on the right (50,000–200,000) are strong outliers.
# Most data points are clustered near the lower range, with very few spread across the higher range.

# %%
df["Discount Rate (%)"].hist()
# Out:
# <Axes: >

# %% [raw]
# The data has more values on the higher side (15–20)Very few values on the lower side (5–10).
# So the distribution is left-skewed.
# There is a big gap around 12–14, showing two separate groups of values.
# The very small values (5–7) may be outliers because they occur rarely.

# %%
df["Discount Amount"].hist()
# Out:
# <Axes: >

# %% [raw]
# The data is right-skewed — most values are small, and a few are very large.
# Outliers are present — rare high values stretch the graph to the right.
# Most entries are low, a few big ones pull the average up, and the data is not evenly spread.

# %%
df["Net Sales Value"].hist()
# Out:
# <Axes: >

# %% [raw]
# SKEWNESS - The histogram is right-skewed. Most values are concentrated between 0 and 25000 ,and  few extend up to 60000
# PRESENCE OF OUTLIERS -  A few values stretch far to the right (up to 175,000), showing rare but very large entries.
# INFERENCE - - - The data is not evenly spread — most values are small, and a few very large ones pull the average up.

# %%
#Box Plots:
#	Create boxplots for numerical variables to identify outliers and the interquartile range.
#	Discuss any findings, such as extreme values or unusual distributions.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Volume"],vert=False)
plt.xlabel("Volume")
plt.ylabel("Avg Price")
plt.show()

# %% [raw]
# Points from 10 to 30+ are extreme outliers, making the data clearly right-skewed.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Avg Price"],vert=False)
plt.xlabel("Avg Price")
plt.ylabel("Volume")
plt.show()

# %% [raw]
# Points from 20000 to 600000 but between 20000 t0 50000 there are no data points  are extreme outliers, making the data clearly right-skewed.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Total Sales Value"],vert=False)
plt.xlabel("Total Sales Value")
plt.ylabel("Discount Rate (%)")
plt.show()

# %% [raw]
# Most values are concentrated at low sales amounts, with a few very high sales forming clear extreme outliers.
# The distribution is strongly right-skewed.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Discount Rate (%)"],vert=False)
plt.xlabel("Discount Rate (%)")
plt.ylabel("Total Sales Value")
plt.show()

# %% [raw]
# The lower discount range (5–8%) has many outliers, showing unusually high sales values there ,The data is in left skewed.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Discount Amount"],vert=False)
plt.xlabel("Discount Amount")
plt.ylabel("Net Sales Value")
plt.show()

# %% [raw]
# Most discount amounts lie in the low range (0–5000), while several very high values (up to 25,000+) appear as extreme outliers.
# The data is right-skewed, with a long tail caused by unusually large discount amounts.

# %%
import matplotlib.pyplot as plt 
plt.boxplot(x=df["Net Sales Value"],vert=False)
plt.xlabel("Net Sales Value")
plt.ylabel("Discount Amount")
plt.show()

# %% [raw]
# Most net sales values fall in the lower range, while very high sales values (above 120,000) appear as clear outliers.
# The distribution is right-skewed, with a long tail caused by these unusually large sales amounts.

# %%
#	Bar Chart Analysis for Categorical Column:
#	Identify categorical columns in the dataset.
#	Create bar charts to visualize the frequency or count of each category.
#	Analyze the distribution of categories and provide insights.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.select_dtypes(include=['object'])
# Out:
#            Date       Day  SKU City         BU  Brand       Model
# 0    01-04-2021  Thursday  M01    C    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
df['Date'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Day'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Day'>

# %%
df['SKU'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SKU'>

# %%
df['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
df['BU'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BU'>

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %% [raw]
#   Summarize the key findings from the descriptive analytics and data visualizations.
# Most values are low, while a few very high values create extreme outliers and right-skewed distributions.
# The main data is tightly clustered, showing consistent patterns, but categories and numeric values are imbalanced.
# Overall, the dataset shows uneven distribution, with a small number of large transactions influencing the results.
