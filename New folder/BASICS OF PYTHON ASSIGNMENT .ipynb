# %%
#Exercise -1  PRIME NUMBERS 
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number:  56
# 56 is not a prime number

# %%
# EXercise -2  Product of Random Numbers
num1 = int(input("Enter FIRST Number:"))
num2 = int(input("Enter SECOND Number :"))
print("What is", num1, "*", num2, "?")
answer = int(input("Enter your answer: "))

# Check the answer using if–else
if answer == num1 * num2:
    print("Correct! Well done.")
else:
    print("Incorrect. The correct answer is", num1 * num2)

# %%
# Exercise - 3 Squares of Even/ Odd Numbers 
for i in range(100,201):
   if i % 2 == 0:
      print(i**2)
# Out:
# 10000
# 10404
# 10816
# 11236
# 11664
# 12100
# 12544
# 12996
# 13456
# 13924
# 14400
# 14884
# 15376
# 15876
# 16384
# 16900
# 17424
# 17956
# 18496
# 19044
# 19600
# 20164
# 20736
# 21316
# 21904
# 22500
# 23104
# 23716
# 24336
# 24964
# 25600
# 26244
# 26896
# 27556
# 28224
# 28900
# 29584
# 30276
# 30976
# 31684
# 32400
# 33124
# 33856
# 34596
# 35344
# 36100
# 36864
# 37636
# 38416
# 39204
# 40000

# %%
# Exercise -4  Problem Statement (Question): Hospital Billing System

Room_charges_per_day =2000
Doctor_consultation_fee =1500
#Based on the number of tests taken. Each test costs ₹300
Lab_test_charges_for_one = 300 


Medicine_charges = int(input("medicine provide"))
stayed_days=int(input("no of days stayed"))
no_of_test_by_patient =int(input("no of test"))



total_for_room_charge = 2000*stayed_days
#print("ROOM CHARGE:",total_for_room_charge)
total_for_lab_test = 300* no_of_test_by_patient
#print("TOTAL FOR MONEY",total_for_lab_test)
total_before_discount = Doctor_consultation_fee + total_for_room_charge+total_for_lab_test+Medicine_charges 
#print("TOTAL BEFORE DISCOUNT",total_before_discount)



if total_before_discount > 10000:
    discount = total_before_discount * 0.10 
else: 
    discount =0
final_bill = total_before_discount - discount
print(final_bill)
# Out:
# medicine provide 2400
# no of days stayed 4
# no of test 3
# 11520.0
